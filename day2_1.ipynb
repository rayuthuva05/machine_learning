# %%
import numpy as np
import pandas as pd
df1=pd.DataFrame(np.random.rand(10,4),columns=('col1','col2','col3','col4'))

# %%
print(df1)
# Out:
#        col1      col2      col3      col4
# 0  0.919855  0.510451  0.095005  0.470476
# 1  0.395749  0.830622  0.221425  0.689612
# 2  0.510676  0.004429  0.995903  0.150088
# 3  0.429834  0.639100  0.154204  0.228976
# 4  0.565414  0.259273  0.576814  0.958018
# 5  0.836366  0.226885  0.197337  0.017517
# 6  0.246252  0.581581  0.364408  0.064375
# 7  0.706696  0.903438  0.967002  0.516387
# 8  0.199358  0.866201  0.114572  0.308984
# 9  0.313825  0.945822  0.974982  0.266974

# %%
df1.plot()
# Out:
# <AxesSubplot:>

# %%
df1.plot(subplots=True,figsize=(8,8))
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#       dtype=object)

# %%
#the kind of plot to produce
#line - line the plot
#bar - vertical bar plot
#hist - histogram
#

# %%
df1.plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
df1.plot(kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1.plot(kind="box")
# Out:
# <AxesSubplot:>

# %%
df1.plot(kind="kde")
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df1.plot(kind="density")
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df1.plot(kind="area")
# Out:
# <AxesSubplot:>

# %%
df1.plot(kind="pie",subplots=True)
# Out:
# array([<AxesSubplot:ylabel='col1'>, <AxesSubplot:ylabel='col2'>,
#        <AxesSubplot:ylabel='col3'>, <AxesSubplot:ylabel='col4'>],
#       dtype=object)

# %%
df1.plot(kind="scatter", x='col1',y='col2')
# Out:
# <AxesSubplot:xlabel='col1', ylabel='col2'>

# %%
df1.plot(kind="hexbin",x='col3',y='col4')
# Out:
# <AxesSubplot:xlabel='col3', ylabel='col4'>

# %%
df1.plot(kind="pie",y="col1")
# Out:
# <AxesSubplot:ylabel='col1'>
